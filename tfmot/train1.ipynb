# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
from sklearn.utils import class_weight
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
import tensorflow_model_optimization as tfmot #     [TFMOT] Nhúng thư viện tối ưu hóa
import numpy as np
import pandas as pd
import glob
from PIL import Image

# ==========================================
# CẤU HÌNH THÔNG SỐ
# ==========================================
IMG_SIZE = 32
NUM_CLASSES = 10
EPOCHS = 100
BATCH_SIZE = 32
DROPOUT_RATE = 0.35
EASTOP = 30
REDUCELR = 6
MINLR = 0.5e-5
VAL_SPLIT = 0.3
DENSE = 64
ALPHA= 0.25
# Most impact on Accuracy - Inference - Size: 
# + Expansion của Bottleneck
# + Kết hợp Recycle Learning Rate - Dropout - Các block của Bottleneck



# DATA ======================================================================
# ĐƯỜNG DẪN DATASET
TRAIN_DIR = 'C:/DUT/Ki_2/Edge_AI/dataset/train'
TEST_DIR = 'C:/DUT/Ki_2/Edge_AI/dataset/test'

# DATA AUGMENTATION
# data_augmentation = tf.keras.Sequential([
#     layers.RandomContrast(0.1, seed=123),
#     layers.RandomZoom(0.05, seed=123, fill_mode='nearest'),      
#     layers.RandomRotation(0.05, seed=123, fill_mode='nearest'),
#     layers.RandomTranslation(0.05, 0.05, seed=123, fill_mode='nearest'), 
#     layers.RandomBrightness(factor=0.05, value_range=(0.0, 1.0), seed=123)
# ])
data_augmentation = tf.keras.Sequential([
    layers.RandomContrast(0.2, seed=123),
    layers.RandomZoom(0.15, seed=123, fill_mode='nearest'),      
    layers.RandomRotation(0.1, seed=123, fill_mode='nearest'),
    layers.RandomTranslation(0.1, 0.1, seed=123, fill_mode='nearest'), 
    layers.RandomBrightness(factor=0.2, value_range=(0.0, 1.0), seed=123)
])
# Thêm hàm chuyển đổi One-Hot cho Dataset
def to_one_hot(image, label):
    # NUM_CLASSES = 10
    one_hot_label = tf.one_hot(label, depth=NUM_CLASSES)
    return image, one_hot_label
normalization_layer = layers.Rescaling(1./255)
AUTOTUNE = tf.data.AUTOTUNE


train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    validation_split=VAL_SPLIT,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode='grayscale'
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    validation_split=VAL_SPLIT,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode='grayscale'
)


train_ds = (
    train_ds
    # 1. Chuẩn hóa ảnh (0-1)
    .map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)
    # 2. Chuyển nhãn sang One-Hot (Bắt buộc để dùng Label Smoothing)
    .map(lambda x, y: to_one_hot(x, y), num_parallel_calls=AUTOTUNE)
    # 3. Cache dữ liệu đã chuẩn hóa và One-hot
    .cache()  
    # 4. Shuffle (Dùng buffer_size vừa đủ để không tràn RAM)
    .shuffle(buffer_size=1000) 
    # 5. Data Augmentation (Thực hiện TRÊN nhãn One-hot vẫn được, vì Augment chỉ tác động lên x)
    .map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
    # 6. Prefetch để tăng tốc GPU/CPU
    .prefetch(buffer_size=AUTOTUNE)
)
val_ds = (
    val_ds
    # 1. Chuẩn hóa ảnh (0-1)
    .map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)
    # 2. Chuyển nhãn sang One-Hot (Bắt buộc để dùng Label Smoothing)
    .map(lambda x, y: to_one_hot(x, y), num_parallel_calls=AUTOTUNE)
    # 3. Cache dữ liệu đã chuẩn hóa và One-hot
    .cache()  
    # 4. Prefetch để tăng tốc GPU/CPU
    .prefetch(buffer_size=AUTOTUNE)
)
# DATA ======================================================================



# BUILD MODEL ======================================================================
def make_divisible(v, divisor=16, min_value=None):
    """
    Đảm bảo mọi lớp đều có số lượng filter chia hết cho `divisor` (16).
    """
    if min_value is None:
        min_value = divisor
    # Công thức làm tròn đến bội số gần nhất
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Đảm bảo việc làm tròn xuống không làm mất quá 10% số lượng filter
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v

def bottleneck_block(inputs, filters, stride, expansion=6):
    """
    Khối Inverted Residual Block chuẩn MobileNetV2
    """
    in_channels = inputs.shape[-1]
    pointwise_filters = make_divisible(filters * ALPHA)
    
    # Bước 1: Expansion (1x1 Conv) - Phóng to
    # Bỏ qua bước này nếu expansion = 1 (thường dùng ở lớp đầu tiên)
    if expansion > 1:
        x = layers.Conv2D(expansion * in_channels, (1, 1), padding='same', use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu6')(x)
    else:
        x = inputs

    # Bước 2: Depthwise (3x3) - Nơi xử lý STRIDE thay cho MaxPooling
    x = layers.DepthwiseConv2D((3, 3), strides=(stride, stride), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu6')(x)

    # Bước 3: Projection (1x1 Conv) - Bóp nhỏ (Linear Activation)
    x = layers.Conv2D(pointwise_filters, (1, 1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    # LƯU Ý: Không dùng ReLU ở đây để tránh mất mát thông tin (Linear Bottleneck)

    # Bước 4: Residual Connection (Cộng gộp)
    # Chỉ cộng khi kích thước ảnh (stride=1) và số kênh (in_channels == pointwise_filters) không đổi
    if stride == 1 and in_channels == pointwise_filters:
        x = layers.Add()([inputs, x])

    return x

def build_micro_model():
    # Lớp đầu vào
    inputs = layers.Input(shape=(32, 32, 1))

    # Lớp Conv đầu tiên: Có thể dùng stride=2 ngay tại đây để giảm RAM lập tức
    # Ảnh 32x32 sẽ biến thành 16x16 ngay sau lớp này
    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu6')(x)

    # Thay thế cụm SeparableConv2D + MaxPooling bằng Bottleneck + Stride=2
    # Đầu vào: 16x16x32
    
# Khối 1: 16x16 -> 8x8 (Expansion=4)
    x = bottleneck_block(x, filters=64, stride=2, expansion=2)
    
    # Khối 2: 8x8 -> 4x4 (Expansion=6)
    x = bottleneck_block(x, filters=128, stride=2, expansion=4)

    # Thêm SpatialDropout2D ở đây để tránh học vẹt
    # x = layers.SpatialDropout2D(0.1)(x)
    
    # Khối 3 & 4: Giữ 4x4 để học sâu hơn (Deep Features)
    # Thêm một khối nữa ở đây giúp model nhận diện tốt hơn các chi tiết nhỏ
    x = bottleneck_block(x, filters=128, stride=1, expansion=6)
    # x = bottleneck_block(x, filters=128, stride=1, expansion=10)
    # x = bottleneck_block(x, filters=128, stride=1, expansion=12)
    # Best: 5 block, Conv2D 64

    # Thêm SpatialDropout2D ở đây để tránh học vẹt trước khi nén thông tin
    x = layers.SpatialDropout2D(0.15)(x)
    # Đóng gói và xuất kết quả
    x = layers.GlobalAveragePooling2D()(x)
    # Thêm 1 lớp Dropout nhẹ trước khi ra kết quả cuối
    x = layers.Dropout(DROPOUT_RATE)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# Khởi tạo model gốc
base_model = build_micro_model()
# Câu trả lời cực kỳ thú vị: AI Instruction không làm Bottleneck nhanh hơn SeparableConv, nhưng nó làm cho khoảng cách về tốc độ giữa hai cái này trở nên cực kỳ nhỏ.
# BUILD MODEL ======================================================================



# CALLBACK ======================================================================
class AccuracyTracker(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.best_val_acc = 0.0
        self.best_val_loss = 10.0
        self.count_epochs = 0

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get("val_accuracy")
        current_val_loss = logs.get("val_loss")
        if current_val_acc > self.best_val_acc:
            diff = current_val_acc - self.best_val_acc
            print(f"\n✅ Epoch {epoch+1}: Val-Accuracy tăng thêm {diff:.4f}! (Từ {self.best_val_acc:.4f} -> {current_val_acc:.4f})")
            self.best_val_acc = current_val_acc
        if self.best_val_acc == 1.0:
            print(f"\n🎉 Epoch {epoch+1}: Val-Accuracy đã đạt 100%!")
        if current_val_loss < self.best_val_loss:
            self.count_epochs = 0
            diff = self.best_val_loss - current_val_loss
            print(f"\n✅ Epoch {epoch+1}: Val-Loss giảm thêm {diff:.4f}! (Từ {self.best_val_loss:.4f} -> {current_val_loss:.4f})")
            self.best_val_loss = current_val_loss
        else:
            self.count_epochs += 1
            print(f"\n⚠️ Val-loss không cải thiện sau {self.count_epochs} epochs. Hiện tại: {current_val_loss:.4f}")

checkpoint = callbacks.ModelCheckpoint(
    'traffic_sign_cleaned_final.h5', 
    monitor='val_loss', 
    save_best_only=True, 
    mode='min',
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_accuracy', 
    factor=0.2, 
    patience=REDUCELR, 
    min_lr=MINLR, 
    verbose=1
)

early_stopping = callbacks.EarlyStopping(
    monitor='val_accuracy', 
    patience=EASTOP, 
    restore_best_weights=True,
    verbose=1
)

callbacks_list = [
    AccuracyTracker(), 
    # reduce_lr, 
    checkpoint, 
    early_stopping,
    # tfmot.sparsity.keras.UpdatePruningStep() # Cập nhật mức độ Pruning sau mỗi step
]
# CALLBACK ======================================================================



# QUANTIZATION AWARE TRAINING ======================================================================
lr_schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate=2e-3, # Adam chạy tốt nhất ở mức này khi bắt đầu
    first_decay_steps=len(train_ds) * 10, # Chu kỳ đầu 10 epoch để học nhanh
    t_mul=1.5, # Đừng để 2.0 (quá dài), 1.5 giúp các chu kỳ sau cân bằng hơn
    m_mul=0.6, # Giảm đỉnh mạnh hơn một chút để Adam hội tụ sâu
    alpha=1e-7 # LR cực thấp ở cuối mỗi chu kỳ để "vắt" Accuracy
)
# Khởi tạo API của tfmot cho QAT
quantize_model = tfmot.quantization.keras.quantize_model
# Bọc mô hình cơ sở bằng các "node giả lập lượng tử"
qat_model = quantize_model(base_model)

# --------------------------------------------------------------------
# Lưu ý: Chúng ta chỉ lấy y (nhãn), bỏ qua x (ảnh) để tiết kiệm RAM
y_one_hot = np.concatenate([y for x, y in train_ds], axis=0)

# 2. Chuyển từ One-Hot back về số nguyên (Label Encoding)
# Ví dụ: [0, 0, 1] -> 2
y_labels = np.argmax(y_one_hot, axis=1)

# 3. Tính toán trọng số tự động dựa trên độ mất cân bằng
weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_labels),
    y=y_labels
)
# 4. Tạo dictionary để nạp vào hàm fit
class_weight_dict = dict(enumerate(weights))
# --------------------------------------------------------------------

# Compile mô hình QAT (Phải compile lại sau khi bọc)
qat_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)
qat_model.summary()

history = qat_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks_list,
    class_weight=class_weight_dict
)

# Bây giờ mới lưu file h5 chuẩn để load sau này mà không bị mismatch
print("✅ Đã lưu mô hình sạch sẽ cho QAT: traffic_sign_cleaned_final.h5")
# QUANTIZATION AWARE TRAINING ======================================================================
# Out:
# WARNING:tensorflow:From c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Found 9629 files belonging to 10 classes.
# Using 6741 files for training.
# Found 9629 files belonging to 10 classes.
# Using 2888 files for validation.
# WARNING:tensorflow:From c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]          0         []
#
#  quantize_layer (QuantizeLa  (None, 32, 32, 1)            3         ['input_1[0][0]']
#  yer)
#
#  quant_conv2d (QuantizeWrap  (None, 16, 16, 64)           705       ['quantize_layer[0][0]']
#  perV2)
#
#  quant_batch_normalization   (None, 16, 16, 64)           259       ['quant_conv2d[0][0]']
#  (QuantizeWrapperV2)
#
#  quant_activation (Quantize  (None, 16, 16, 64)           3         ['quant_batch_normalization[0]
#  WrapperV2)                                                         [0]']
#
#  quant_conv2d_1 (QuantizeWr  (None, 16, 16, 128)          8449      ['quant_activation[0][0]']
#  apperV2)
#
#  quant_batch_normalization_  (None, 16, 16, 128)          515       ['quant_conv2d_1[0][0]']
#  1 (QuantizeWrapperV2)
#
#  quant_activation_1 (Quanti  (None, 16, 16, 128)          3         ['quant_batch_normalization_1[
#  zeWrapperV2)                                                       0][0]']
#
#  quant_depthwise_conv2d (Qu  (None, 8, 8, 128)            1155      ['quant_activation_1[0][0]']
#  antizeWrapperV2)
#
#  quant_batch_normalization_  (None, 8, 8, 128)            515       ['quant_depthwise_conv2d[0][0]
#  2 (QuantizeWrapperV2)                                              ']
#
#  quant_activation_2 (Quanti  (None, 8, 8, 128)            3         ['quant_batch_normalization_2[
#  zeWrapperV2)                                                       0][0]']
#
#  quant_conv2d_2 (QuantizeWr  (None, 8, 8, 16)             2081      ['quant_activation_2[0][0]']
#  apperV2)
#
#  quant_batch_normalization_  (None, 8, 8, 16)             67        ['quant_conv2d_2[0][0]']
#  3 (QuantizeWrapperV2)
#
#  quant_conv2d_3 (QuantizeWr  (None, 8, 8, 64)             1153      ['quant_batch_normalization_3[
#  apperV2)                                                           0][0]']
#
#  quant_batch_normalization_  (None, 8, 8, 64)             259       ['quant_conv2d_3[0][0]']
#  4 (QuantizeWrapperV2)
#
#  quant_activation_3 (Quanti  (None, 8, 8, 64)             3         ['quant_batch_normalization_4[
#  zeWrapperV2)                                                       0][0]']
#
#  quant_depthwise_conv2d_1 (  (None, 4, 4, 64)             579       ['quant_activation_3[0][0]']
#  QuantizeWrapperV2)
#
#  quant_batch_normalization_  (None, 4, 4, 64)             259       ['quant_depthwise_conv2d_1[0][
#  5 (QuantizeWrapperV2)                                              0]']
#
#  quant_activation_4 (Quanti  (None, 4, 4, 64)             3         ['quant_batch_normalization_5[
#  zeWrapperV2)                                                       0][0]']
#
#  quant_conv2d_4 (QuantizeWr  (None, 4, 4, 32)             2113      ['quant_activation_4[0][0]']
#  apperV2)
#
#  quant_batch_normalization_  (None, 4, 4, 32)             131       ['quant_conv2d_4[0][0]']
#  6 (QuantizeWrapperV2)
#
#  quant_conv2d_5 (QuantizeWr  (None, 4, 4, 192)            6529      ['quant_batch_normalization_6[
#  apperV2)                                                           0][0]']
#
#  quant_batch_normalization_  (None, 4, 4, 192)            771       ['quant_conv2d_5[0][0]']
#  7 (QuantizeWrapperV2)
#
#  quant_activation_5 (Quanti  (None, 4, 4, 192)            3         ['quant_batch_normalization_7[
#  zeWrapperV2)                                                       0][0]']
#
#  quant_depthwise_conv2d_2 (  (None, 4, 4, 192)            1731      ['quant_activation_5[0][0]']
#  QuantizeWrapperV2)
#
#  quant_batch_normalization_  (None, 4, 4, 192)            771       ['quant_depthwise_conv2d_2[0][
#  8 (QuantizeWrapperV2)                                              0]']
#
#  quant_activation_6 (Quanti  (None, 4, 4, 192)            3         ['quant_batch_normalization_8[
#  zeWrapperV2)                                                       0][0]']
#
#  quant_conv2d_6 (QuantizeWr  (None, 4, 4, 32)             6209      ['quant_activation_6[0][0]']
#  apperV2)
#
#  quant_batch_normalization_  (None, 4, 4, 32)             131       ['quant_conv2d_6[0][0]']
#  9 (QuantizeWrapperV2)
#
#  quant_add (QuantizeWrapper  (None, 4, 4, 32)             3         ['quant_batch_normalization_6[
#  V2)                                                                0][0]',
#                                                                      'quant_batch_normalization_9[
#                                                                     0][0]']
#
#  quant_spatial_dropout2d (Q  (None, 4, 4, 32)             1         ['quant_add[0][0]']
#  uantizeWrapperV2)
#
#  quant_global_average_pooli  (None, 32)                   3         ['quant_spatial_dropout2d[0][0
#  ng2d (QuantizeWrapperV2)                                           ]']
#
#  quant_dropout (QuantizeWra  (None, 32)                   1         ['quant_global_average_pooling
#  pperV2)                                                            2d[0][0]']
#
#  quant_dense (QuantizeWrapp  (None, 10)                   335       ['quant_dropout[0][0]']
#  erV2)
#
# ==================================================================================================
# Total params: 34749 (135.74 KB)
# Trainable params: 31786 (124.16 KB)
# Non-trainable params: 2963 (11.57 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 211/211 [==============================] - ETA: 0s - loss: 2.3043 - accuracy: 0.1710 - precision: 0.1731 - recall: 0.0027
# ✅ Epoch 1: Val-Accuracy tăng thêm 0.2192! (Từ 0.0000 -> 0.2192)
#
# ✅ Epoch 1: Val-Loss giảm thêm 7.7849! (Từ 10.0000 -> 2.2151)
#
# Epoch 1: val_loss improved from inf to 2.21514, saving model to traffic_sign_cleaned_final.h5
# c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\engine\training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 211/211 [==============================] - 36s 125ms/step - loss: 2.3043 - accuracy: 0.1710 - precision: 0.1731 - recall: 0.0027 - val_loss: 2.2151 - val_accuracy: 0.2192 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 210/211 [============================>.] - ETA: 0s - loss: 2.0376 - accuracy: 0.3109 - precision: 0.7354 - recall: 0.0282
# ✅ Epoch 2: Val-Accuracy tăng thêm 0.0211! (Từ 0.2192 -> 0.2403)
#
# ✅ Epoch 2: Val-Loss giảm thêm 0.1242! (Từ 2.2151 -> 2.0910)
#
# Epoch 2: val_loss improved from 2.21514 to 2.09095, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 10s 46ms/step - loss: 2.0373 - accuracy: 0.3117 - precision: 0.7346 - recall: 0.0283 - val_loss: 2.0910 - val_accuracy: 0.2403 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 211/211 [==============================] - ETA: 0s - loss: 1.7308 - accuracy: 0.4766 - precision: 0.7851 - recall: 0.1426
# ✅ Epoch 3: Val-Accuracy tăng thêm 0.2812! (Từ 0.2403 -> 0.5215)
#
# ✅ Epoch 3: Val-Loss giảm thêm 0.4829! (Từ 2.0910 -> 1.6081)
#
# Epoch 3: val_loss improved from 2.09095 to 1.60807, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 25s 118ms/step - loss: 1.7308 - accuracy: 0.4766 - precision: 0.7851 - recall: 0.1426 - val_loss: 1.6081 - val_accuracy: 0.5215 - val_precision: 0.8376 - val_recall: 0.2517
# Epoch 4/100
# 211/211 [==============================] - ETA: 0s - loss: 1.4588 - accuracy: 0.6101 - precision: 0.8646 - recall: 0.3126
# ✅ Epoch 4: Val-Accuracy tăng thêm 0.1949! (Từ 0.5215 -> 0.7164)
#
# ✅ Epoch 4: Val-Loss giảm thêm 0.3384! (Từ 1.6081 -> 1.2696)
#
# Epoch 4: val_loss improved from 1.60807 to 1.26962, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 25s 119ms/step - loss: 1.4588 - accuracy: 0.6101 - precision: 0.8646 - recall: 0.3126 - val_loss: 1.2696 - val_accuracy: 0.7164 - val_precision: 0.9330 - val_recall: 0.4290
# Epoch 5/100
# 211/211 [==============================] - ETA: 0s - loss: 1.3063 - accuracy: 0.6768 - precision: 0.8767 - recall: 0.4231
# ✅ Epoch 5: Val-Accuracy tăng thêm 0.1856! (Từ 0.7164 -> 0.9020)
#
# ✅ Epoch 5: Val-Loss giảm thêm 0.4086! (Từ 1.2696 -> 0.8611)
#
# Epoch 5: val_loss improved from 1.26962 to 0.86106, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 24s 114ms/step - loss: 1.3063 - accuracy: 0.6768 - precision: 0.8767 - recall: 0.4231 - val_loss: 0.8611 - val_accuracy: 0.9020 - val_precision: 0.9689 - val_recall: 0.7663
# Epoch 6/100
# 211/211 [==============================] - ETA: 0s - loss: 1.1781 - accuracy: 0.7333 - precision: 0.9137 - recall: 0.5152
# ✅ Epoch 6: Val-Accuracy tăng thêm 0.0225! (Từ 0.9020 -> 0.9245)
#
# ✅ Epoch 6: Val-Loss giảm thêm 0.0647! (Từ 0.8611 -> 0.7963)
#
# Epoch 6: val_loss improved from 0.86106 to 0.79632, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 24s 114ms/step - loss: 1.1781 - accuracy: 0.7333 - precision: 0.9137 - recall: 0.5152 - val_loss: 0.7963 - val_accuracy: 0.9245 - val_precision: 0.9770 - val_recall: 0.8248
# Epoch 7/100
# 211/211 [==============================] - ETA: 0s - loss: 1.0911 - accuracy: 0.7779 - precision: 0.9264 - recall: 0.5937
# ✅ Epoch 7: Val-Accuracy tăng thêm 0.0201! (Từ 0.9245 -> 0.9446)
#
# ✅ Epoch 7: Val-Loss giảm thêm 0.0462! (Từ 0.7963 -> 0.7502)
#
# Epoch 7: val_loss improved from 0.79632 to 0.75015, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 20s 96ms/step - loss: 1.0911 - accuracy: 0.7779 - precision: 0.9264 - recall: 0.5937 - val_loss: 0.7502 - val_accuracy: 0.9446 - val_precision: 0.9853 - val_recall: 0.8605
# Epoch 8/100
# 211/211 [==============================] - ETA: 0s - loss: 1.0443 - accuracy: 0.8092 - precision: 0.9382 - recall: 0.6373
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.7644
#
# Epoch 8: val_loss did not improve from 0.75015
# 211/211 [==============================] - 29s 136ms/step - loss: 1.0443 - accuracy: 0.8092 - precision: 0.9382 - recall: 0.6373 - val_loss: 0.7644 - val_accuracy: 0.9339 - val_precision: 0.9775 - val_recall: 0.8580
# Epoch 9/100
# 210/211 [============================>.] - ETA: 0s - loss: 1.0088 - accuracy: 0.8186 - precision: 0.9341 - recall: 0.6570
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.7538
#
# Epoch 9: val_loss did not improve from 0.75015
# 211/211 [==============================] - 29s 136ms/step - loss: 1.0081 - accuracy: 0.8186 - precision: 0.9338 - recall: 0.6567 - val_loss: 0.7538 - val_accuracy: 0.9411 - val_precision: 0.9757 - val_recall: 0.8771
# Epoch 10/100
# 210/211 [============================>.] - ETA: 0s - loss: 1.0041 - accuracy: 0.8247 - precision: 0.9431 - recall: 0.6602
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.7522
#
# Epoch 10: val_loss did not improve from 0.75015
# 211/211 [==============================] - 17s 79ms/step - loss: 1.0026 - accuracy: 0.8251 - precision: 0.9432 - recall: 0.6603 - val_loss: 0.7522 - val_accuracy: 0.9418 - val_precision: 0.9766 - val_recall: 0.8809
# Epoch 11/100
# 210/211 [============================>.] - ETA: 0s - loss: 1.0445 - accuracy: 0.7952 - precision: 0.9280 - recall: 0.6278
# ⚠️ Val-loss không cải thiện sau 4 epochs. Hiện tại: 0.8242
#
# Epoch 11: val_loss did not improve from 0.75015
# 211/211 [==============================] - 13s 63ms/step - loss: 1.0446 - accuracy: 0.7954 - precision: 0.9281 - recall: 0.6281 - val_loss: 0.8242 - val_accuracy: 0.9075 - val_precision: 0.9482 - val_recall: 0.8490
# Epoch 12/100
# 211/211 [==============================] - ETA: 0s - loss: 1.0547 - accuracy: 0.7965 - precision: 0.9246 - recall: 0.6364
# ⚠️ Val-loss không cải thiện sau 5 epochs. Hiện tại: 0.9304
#
# Epoch 12: val_loss did not improve from 0.75015
# 211/211 [==============================] - 14s 65ms/step - loss: 1.0547 - accuracy: 0.7965 - precision: 0.9246 - recall: 0.6364 - val_loss: 0.9304 - val_accuracy: 0.8470 - val_precision: 0.9056 - val_recall: 0.7739
# Epoch 13/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.9793 - accuracy: 0.8320 - precision: 0.9388 - recall: 0.6927
# ⚠️ Val-loss không cải thiện sau 6 epochs. Hiện tại: 0.7988
#
# Epoch 13: val_loss did not improve from 0.75015
# 211/211 [==============================] - 13s 62ms/step - loss: 0.9786 - accuracy: 0.8325 - precision: 0.9391 - recall: 0.6932 - val_loss: 0.7988 - val_accuracy: 0.9127 - val_precision: 0.9456 - val_recall: 0.8553
# Epoch 14/100
# 211/211 [==============================] - ETA: 0s - loss: 0.9642 - accuracy: 0.8379 - precision: 0.9431 - recall: 0.7011
# ⚠️ Val-loss không cải thiện sau 7 epochs. Hiện tại: 0.7864
#
# Epoch 14: val_loss did not improve from 0.75015
# 211/211 [==============================] - 10s 47ms/step - loss: 0.9642 - accuracy: 0.8379 - precision: 0.9431 - recall: 0.7011 - val_loss: 0.7864 - val_accuracy: 0.9183 - val_precision: 0.9616 - val_recall: 0.8584
# Epoch 15/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.9480 - accuracy: 0.8506 - precision: 0.9516 - recall: 0.7150
# ✅ Epoch 15: Val-Loss giảm thêm 0.0021! (Từ 0.7502 -> 0.7481)
#
# Epoch 15: val_loss improved from 0.75015 to 0.74808, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 10s 46ms/step - loss: 0.9475 - accuracy: 0.8505 - precision: 0.9512 - recall: 0.7149 - val_loss: 0.7481 - val_accuracy: 0.9359 - val_precision: 0.9636 - val_recall: 0.8989
# Epoch 16/100
# 211/211 [==============================] - ETA: 0s - loss: 0.9080 - accuracy: 0.8610 - precision: 0.9515 - recall: 0.7394
# ✅ Epoch 16: Val-Accuracy tăng thêm 0.0163! (Từ 0.9446 -> 0.9609)
#
# ✅ Epoch 16: Val-Loss giảm thêm 0.0478! (Từ 0.7481 -> 0.7002)
#
# Epoch 16: val_loss improved from 0.74808 to 0.70023, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 10s 49ms/step - loss: 0.9080 - accuracy: 0.8610 - precision: 0.9515 - recall: 0.7394 - val_loss: 0.7002 - val_accuracy: 0.9609 - val_precision: 0.9827 - val_recall: 0.9266
# Epoch 17/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8708 - accuracy: 0.8809 - precision: 0.9612 - recall: 0.7579
# ✅ Epoch 17: Val-Accuracy tăng thêm 0.0045! (Từ 0.9609 -> 0.9654)
#
# ✅ Epoch 17: Val-Loss giảm thêm 0.0210! (Từ 0.7002 -> 0.6792)
#
# Epoch 17: val_loss improved from 0.70023 to 0.67924, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 11s 51ms/step - loss: 0.8703 - accuracy: 0.8807 - precision: 0.9612 - recall: 0.7579 - val_loss: 0.6792 - val_accuracy: 0.9654 - val_precision: 0.9839 - val_recall: 0.9325
# Epoch 18/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8714 - accuracy: 0.8831 - precision: 0.9563 - recall: 0.7640
# ✅ Epoch 18: Val-Accuracy tăng thêm 0.0055! (Từ 0.9654 -> 0.9709)
#
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6840
#
# Epoch 18: val_loss did not improve from 0.67924
# 211/211 [==============================] - 13s 60ms/step - loss: 0.8712 - accuracy: 0.8831 - precision: 0.9565 - recall: 0.7641 - val_loss: 0.6840 - val_accuracy: 0.9709 - val_precision: 0.9859 - val_recall: 0.9460
# Epoch 19/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8552 - accuracy: 0.8887 - precision: 0.9626 - recall: 0.7818
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6840
#
# Epoch 19: val_loss did not improve from 0.67924
# 211/211 [==============================] - 10s 49ms/step - loss: 0.8552 - accuracy: 0.8887 - precision: 0.9626 - recall: 0.7818 - val_loss: 0.6840 - val_accuracy: 0.9675 - val_precision: 0.9858 - val_recall: 0.9342
# Epoch 20/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8449 - accuracy: 0.8950 - precision: 0.9708 - recall: 0.7834
# ✅ Epoch 20: Val-Loss giảm thêm 0.0029! (Từ 0.6792 -> 0.6763)
#
# Epoch 20: val_loss improved from 0.67924 to 0.67631, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 19s 90ms/step - loss: 0.8449 - accuracy: 0.8950 - precision: 0.9708 - recall: 0.7834 - val_loss: 0.6763 - val_accuracy: 0.9699 - val_precision: 0.9830 - val_recall: 0.9411
# Epoch 21/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8210 - accuracy: 0.8982 - precision: 0.9659 - recall: 0.7978
# ✅ Epoch 21: Val-Accuracy tăng thêm 0.0024! (Từ 0.9709 -> 0.9733)
#
# ✅ Epoch 21: Val-Loss giảm thêm 0.0120! (Từ 0.6763 -> 0.6643)
#
# Epoch 21: val_loss improved from 0.67631 to 0.66432, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 31s 145ms/step - loss: 0.8210 - accuracy: 0.8982 - precision: 0.9659 - recall: 0.7978 - val_loss: 0.6643 - val_accuracy: 0.9733 - val_precision: 0.9857 - val_recall: 0.9519
# Epoch 22/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8173 - accuracy: 0.9048 - precision: 0.9707 - recall: 0.8046
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6704
#
# Epoch 22: val_loss did not improve from 0.66432
# 211/211 [==============================] - 31s 145ms/step - loss: 0.8173 - accuracy: 0.9048 - precision: 0.9707 - recall: 0.8046 - val_loss: 0.6704 - val_accuracy: 0.9699 - val_precision: 0.9841 - val_recall: 0.9422
# Epoch 23/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8174 - accuracy: 0.9137 - precision: 0.9724 - recall: 0.8049
# ✅ Epoch 23: Val-Loss giảm thêm 0.0045! (Từ 0.6643 -> 0.6598)
#
# Epoch 23: val_loss improved from 0.66432 to 0.65982, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 28s 131ms/step - loss: 0.8174 - accuracy: 0.9137 - precision: 0.9724 - recall: 0.8049 - val_loss: 0.6598 - val_accuracy: 0.9730 - val_precision: 0.9838 - val_recall: 0.9474
# Epoch 24/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8076 - accuracy: 0.9143 - precision: 0.9740 - recall: 0.8054
# ✅ Epoch 24: Val-Accuracy tăng thêm 0.0024! (Từ 0.9733 -> 0.9758)
#
# ✅ Epoch 24: Val-Loss giảm thêm 0.0000! (Từ 0.6598 -> 0.6598)
#
# Epoch 24: val_loss improved from 0.65982 to 0.65980, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 24s 112ms/step - loss: 0.8076 - accuracy: 0.9143 - precision: 0.9740 - recall: 0.8054 - val_loss: 0.6598 - val_accuracy: 0.9758 - val_precision: 0.9842 - val_recall: 0.9515
# Epoch 25/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8085 - accuracy: 0.9107 - precision: 0.9751 - recall: 0.8049
# ✅ Epoch 25: Val-Loss giảm thêm 0.0009! (Từ 0.6598 -> 0.6589)
#
# Epoch 25: val_loss improved from 0.65980 to 0.65895, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 8s 40ms/step - loss: 0.8092 - accuracy: 0.9105 - precision: 0.9750 - recall: 0.8051 - val_loss: 0.6589 - val_accuracy: 0.9747 - val_precision: 0.9849 - val_recall: 0.9498
# Epoch 26/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8261 - accuracy: 0.9012 - precision: 0.9722 - recall: 0.7933
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6696
#
# Epoch 26: val_loss did not improve from 0.65895
# 211/211 [==============================] - 9s 41ms/step - loss: 0.8264 - accuracy: 0.9012 - precision: 0.9724 - recall: 0.7935 - val_loss: 0.6696 - val_accuracy: 0.9758 - val_precision: 0.9857 - val_recall: 0.9529
# Epoch 27/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8527 - accuracy: 0.8915 - precision: 0.9654 - recall: 0.7901
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.7108
#
# Epoch 27: val_loss did not improve from 0.65895
# 211/211 [==============================] - 9s 41ms/step - loss: 0.8519 - accuracy: 0.8919 - precision: 0.9656 - recall: 0.7907 - val_loss: 0.7108 - val_accuracy: 0.9550 - val_precision: 0.9658 - val_recall: 0.9301
# Epoch 28/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8376 - accuracy: 0.8960 - precision: 0.9675 - recall: 0.7901
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.6849
#
# Epoch 28: val_loss did not improve from 0.65895
# 211/211 [==============================] - 9s 41ms/step - loss: 0.8382 - accuracy: 0.8962 - precision: 0.9675 - recall: 0.7905 - val_loss: 0.6849 - val_accuracy: 0.9612 - val_precision: 0.9821 - val_recall: 0.9304
# Epoch 29/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8348 - accuracy: 0.8994 - precision: 0.9676 - recall: 0.7926
# ✅ Epoch 29: Val-Accuracy tăng thêm 0.0048! (Từ 0.9758 -> 0.9806)
#
# ✅ Epoch 29: Val-Loss giảm thêm 0.0204! (Từ 0.6589 -> 0.6385)
#
# Epoch 29: val_loss improved from 0.65895 to 0.63853, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 41ms/step - loss: 0.8348 - accuracy: 0.8994 - precision: 0.9676 - recall: 0.7926 - val_loss: 0.6385 - val_accuracy: 0.9806 - val_precision: 0.9935 - val_recall: 0.9498
# Epoch 30/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8214 - accuracy: 0.9049 - precision: 0.9713 - recall: 0.8027
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6599
#
# Epoch 30: val_loss did not improve from 0.63853
# 211/211 [==============================] - 9s 44ms/step - loss: 0.8207 - accuracy: 0.9054 - precision: 0.9714 - recall: 0.8024 - val_loss: 0.6599 - val_accuracy: 0.9747 - val_precision: 0.9887 - val_recall: 0.9425
# Epoch 31/100
# 211/211 [==============================] - ETA: 0s - loss: 0.8163 - accuracy: 0.9097 - precision: 0.9666 - recall: 0.8107
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6717
#
# Epoch 31: val_loss did not improve from 0.63853
# 211/211 [==============================] - 9s 41ms/step - loss: 0.8163 - accuracy: 0.9097 - precision: 0.9666 - recall: 0.8107 - val_loss: 0.6717 - val_accuracy: 0.9640 - val_precision: 0.9821 - val_recall: 0.9325
# Epoch 32/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8112 - accuracy: 0.9137 - precision: 0.9763 - recall: 0.8164
# ✅ Epoch 32: Val-Loss giảm thêm 0.0020! (Từ 0.6385 -> 0.6365)
#
# Epoch 32: val_loss improved from 0.63853 to 0.63649, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 43ms/step - loss: 0.8109 - accuracy: 0.9140 - precision: 0.9764 - recall: 0.8168 - val_loss: 0.6365 - val_accuracy: 0.9806 - val_precision: 0.9939 - val_recall: 0.9591
# Epoch 33/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7965 - accuracy: 0.9153 - precision: 0.9755 - recall: 0.8177
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6435
#
# Epoch 33: val_loss did not improve from 0.63649
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7972 - accuracy: 0.9148 - precision: 0.9752 - recall: 0.8172 - val_loss: 0.6435 - val_accuracy: 0.9740 - val_precision: 0.9870 - val_recall: 0.9488
# Epoch 34/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.8061 - accuracy: 0.9173 - precision: 0.9762 - recall: 0.8182
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6553
#
# Epoch 34: val_loss did not improve from 0.63649
# 211/211 [==============================] - 9s 42ms/step - loss: 0.8058 - accuracy: 0.9174 - precision: 0.9761 - recall: 0.8178 - val_loss: 0.6553 - val_accuracy: 0.9685 - val_precision: 0.9884 - val_recall: 0.9404
# Epoch 35/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7899 - accuracy: 0.9223 - precision: 0.9747 - recall: 0.8281
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.6442
#
# Epoch 35: val_loss did not improve from 0.63649
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7899 - accuracy: 0.9223 - precision: 0.9747 - recall: 0.8281 - val_loss: 0.6442 - val_accuracy: 0.9737 - val_precision: 0.9898 - val_recall: 0.9443
# Epoch 36/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7985 - accuracy: 0.9217 - precision: 0.9794 - recall: 0.8286
# ✅ Epoch 36: Val-Loss giảm thêm 0.0004! (Từ 0.6365 -> 0.6361)
#
# Epoch 36: val_loss improved from 0.63649 to 0.63611, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7979 - accuracy: 0.9220 - precision: 0.9793 - recall: 0.8288 - val_loss: 0.6361 - val_accuracy: 0.9754 - val_precision: 0.9878 - val_recall: 0.9560
# Epoch 37/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7749 - accuracy: 0.9288 - precision: 0.9815 - recall: 0.8401
# ✅ Epoch 37: Val-Loss giảm thêm 0.0127! (Từ 0.6361 -> 0.6234)
#
# Epoch 37: val_loss improved from 0.63611 to 0.62338, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 44ms/step - loss: 0.7745 - accuracy: 0.9289 - precision: 0.9816 - recall: 0.8402 - val_loss: 0.6234 - val_accuracy: 0.9799 - val_precision: 0.9921 - val_recall: 0.9591
# Epoch 38/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7536 - accuracy: 0.9367 - precision: 0.9804 - recall: 0.8522
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6327
#
# Epoch 38: val_loss did not improve from 0.62338
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7536 - accuracy: 0.9367 - precision: 0.9804 - recall: 0.8522 - val_loss: 0.6327 - val_accuracy: 0.9754 - val_precision: 0.9864 - val_recall: 0.9515
# Epoch 39/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7553 - accuracy: 0.9364 - precision: 0.9827 - recall: 0.8512
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6398
#
# Epoch 39: val_loss did not improve from 0.62338
# 211/211 [==============================] - 9s 40ms/step - loss: 0.7553 - accuracy: 0.9364 - precision: 0.9827 - recall: 0.8512 - val_loss: 0.6398 - val_accuracy: 0.9726 - val_precision: 0.9842 - val_recall: 0.9494
# Epoch 40/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7562 - accuracy: 0.9362 - precision: 0.9808 - recall: 0.8508
# ✅ Epoch 40: Val-Accuracy tăng thêm 0.0035! (Từ 0.9806 -> 0.9841)
#
# ✅ Epoch 40: Val-Loss giảm thêm 0.0067! (Từ 0.6234 -> 0.6167)
#
# Epoch 40: val_loss improved from 0.62338 to 0.61667, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7555 - accuracy: 0.9365 - precision: 0.9809 - recall: 0.8512 - val_loss: 0.6167 - val_accuracy: 0.9841 - val_precision: 0.9925 - val_recall: 0.9623
# Epoch 41/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7503 - accuracy: 0.9393 - precision: 0.9836 - recall: 0.8574
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6212
#
# Epoch 41: val_loss did not improve from 0.61667
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7502 - accuracy: 0.9390 - precision: 0.9831 - recall: 0.8568 - val_loss: 0.6212 - val_accuracy: 0.9810 - val_precision: 0.9914 - val_recall: 0.9595
# Epoch 42/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7480 - accuracy: 0.9386 - precision: 0.9817 - recall: 0.8583
# ✅ Epoch 42: Val-Loss giảm thêm 0.0015! (Từ 0.6167 -> 0.6152)
#
# Epoch 42: val_loss improved from 0.61667 to 0.61520, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 44ms/step - loss: 0.7480 - accuracy: 0.9386 - precision: 0.9817 - recall: 0.8583 - val_loss: 0.6152 - val_accuracy: 0.9823 - val_precision: 0.9936 - val_recall: 0.9609
# Epoch 43/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7507 - accuracy: 0.9404 - precision: 0.9856 - recall: 0.8577
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6214
#
# Epoch 43: val_loss did not improve from 0.61520
# 211/211 [==============================] - 8s 40ms/step - loss: 0.7513 - accuracy: 0.9402 - precision: 0.9857 - recall: 0.8573 - val_loss: 0.6214 - val_accuracy: 0.9792 - val_precision: 0.9911 - val_recall: 0.9609
# Epoch 44/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7353 - accuracy: 0.9453 - precision: 0.9847 - recall: 0.8612
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6179
#
# Epoch 44: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7352 - accuracy: 0.9454 - precision: 0.9847 - recall: 0.8614 - val_loss: 0.6179 - val_accuracy: 0.9820 - val_precision: 0.9900 - val_recall: 0.9605
# Epoch 45/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7530 - accuracy: 0.9368 - precision: 0.9824 - recall: 0.8594
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.6172
#
# Epoch 45: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7530 - accuracy: 0.9368 - precision: 0.9824 - recall: 0.8594 - val_loss: 0.6172 - val_accuracy: 0.9823 - val_precision: 0.9900 - val_recall: 0.9605
# Epoch 46/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7420 - accuracy: 0.9393 - precision: 0.9848 - recall: 0.8574
# ⚠️ Val-loss không cải thiện sau 4 epochs. Hiện tại: 0.6190
#
# Epoch 46: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7420 - accuracy: 0.9393 - precision: 0.9848 - recall: 0.8574 - val_loss: 0.6190 - val_accuracy: 0.9806 - val_precision: 0.9893 - val_recall: 0.9602
# Epoch 47/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7392 - accuracy: 0.9446 - precision: 0.9844 - recall: 0.8667
# ⚠️ Val-loss không cải thiện sau 5 epochs. Hiện tại: 0.6180
#
# Epoch 47: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7401 - accuracy: 0.9445 - precision: 0.9843 - recall: 0.8666 - val_loss: 0.6180 - val_accuracy: 0.9810 - val_precision: 0.9907 - val_recall: 0.9619
# Epoch 48/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7393 - accuracy: 0.9384 - precision: 0.9849 - recall: 0.8580
# ⚠️ Val-loss không cải thiện sau 6 epochs. Hiện tại: 0.6385
#
# Epoch 48: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7397 - accuracy: 0.9383 - precision: 0.9850 - recall: 0.8580 - val_loss: 0.6385 - val_accuracy: 0.9713 - val_precision: 0.9838 - val_recall: 0.9470
# Epoch 49/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7609 - accuracy: 0.9359 - precision: 0.9834 - recall: 0.8525
# ⚠️ Val-loss không cải thiện sau 7 epochs. Hiện tại: 0.6263
#
# Epoch 49: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7609 - accuracy: 0.9359 - precision: 0.9834 - recall: 0.8525 - val_loss: 0.6263 - val_accuracy: 0.9816 - val_precision: 0.9903 - val_recall: 0.9581
# Epoch 50/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7554 - accuracy: 0.9364 - precision: 0.9816 - recall: 0.8528
# ⚠️ Val-loss không cải thiện sau 8 epochs. Hiện tại: 0.6494
#
# Epoch 50: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7554 - accuracy: 0.9364 - precision: 0.9816 - recall: 0.8528 - val_loss: 0.6494 - val_accuracy: 0.9713 - val_precision: 0.9855 - val_recall: 0.9408
# Epoch 51/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7661 - accuracy: 0.9301 - precision: 0.9786 - recall: 0.8465
# ⚠️ Val-loss không cải thiện sau 9 epochs. Hiện tại: 0.6427
#
# Epoch 51: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7676 - accuracy: 0.9301 - precision: 0.9787 - recall: 0.8463 - val_loss: 0.6427 - val_accuracy: 0.9737 - val_precision: 0.9845 - val_recall: 0.9463
# Epoch 52/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7599 - accuracy: 0.9322 - precision: 0.9820 - recall: 0.8480
# ⚠️ Val-loss không cải thiện sau 10 epochs. Hiện tại: 0.6312
#
# Epoch 52: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7592 - accuracy: 0.9325 - precision: 0.9821 - recall: 0.8484 - val_loss: 0.6312 - val_accuracy: 0.9768 - val_precision: 0.9885 - val_recall: 0.9498
# Epoch 53/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7469 - accuracy: 0.9375 - precision: 0.9837 - recall: 0.8621
# ⚠️ Val-loss không cải thiện sau 11 epochs. Hiện tại: 0.6169
#
# Epoch 53: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7471 - accuracy: 0.9377 - precision: 0.9838 - recall: 0.8625 - val_loss: 0.6169 - val_accuracy: 0.9830 - val_precision: 0.9935 - val_recall: 0.9574
# Epoch 54/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7454 - accuracy: 0.9392 - precision: 0.9837 - recall: 0.8610
# ⚠️ Val-loss không cải thiện sau 12 epochs. Hiện tại: 0.6236
#
# Epoch 54: val_loss did not improve from 0.61520
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7454 - accuracy: 0.9392 - precision: 0.9837 - recall: 0.8610 - val_loss: 0.6236 - val_accuracy: 0.9803 - val_precision: 0.9911 - val_recall: 0.9598
# Epoch 55/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7398 - accuracy: 0.9410 - precision: 0.9837 - recall: 0.8632
# ✅ Epoch 55: Val-Accuracy tăng thêm 0.0010! (Từ 0.9841 -> 0.9851)
#
# ✅ Epoch 55: Val-Loss giảm thêm 0.0059! (Từ 0.6152 -> 0.6093)
#
# Epoch 55: val_loss improved from 0.61520 to 0.60929, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7402 - accuracy: 0.9411 - precision: 0.9838 - recall: 0.8635 - val_loss: 0.6093 - val_accuracy: 0.9851 - val_precision: 0.9936 - val_recall: 0.9605
# Epoch 56/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7420 - accuracy: 0.9420 - precision: 0.9831 - recall: 0.8607
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6323
#
# Epoch 56: val_loss did not improve from 0.60929
# 211/211 [==============================] - 9s 44ms/step - loss: 0.7420 - accuracy: 0.9420 - precision: 0.9831 - recall: 0.8607 - val_loss: 0.6323 - val_accuracy: 0.9744 - val_precision: 0.9857 - val_recall: 0.9571
# Epoch 57/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7412 - accuracy: 0.9448 - precision: 0.9847 - recall: 0.8616
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6314
#
# Epoch 57: val_loss did not improve from 0.60929
# 211/211 [==============================] - 10s 50ms/step - loss: 0.7412 - accuracy: 0.9448 - precision: 0.9847 - recall: 0.8616 - val_loss: 0.6314 - val_accuracy: 0.9720 - val_precision: 0.9840 - val_recall: 0.9571
# Epoch 58/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7484 - accuracy: 0.9381 - precision: 0.9839 - recall: 0.8592
# ✅ Epoch 58: Val-Accuracy tăng thêm 0.0024! (Từ 0.9851 -> 0.9875)
#
# ✅ Epoch 58: Val-Loss giảm thêm 0.0047! (Từ 0.6093 -> 0.6046)
#
# Epoch 58: val_loss improved from 0.60929 to 0.60459, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 27s 129ms/step - loss: 0.7484 - accuracy: 0.9381 - precision: 0.9839 - recall: 0.8592 - val_loss: 0.6046 - val_accuracy: 0.9875 - val_precision: 0.9926 - val_recall: 0.9713
# Epoch 59/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7331 - accuracy: 0.9462 - precision: 0.9855 - recall: 0.8733
# ✅ Epoch 59: Val-Loss giảm thêm 0.0036! (Từ 0.6046 -> 0.6010)
#
# Epoch 59: val_loss improved from 0.60459 to 0.60104, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 8s 40ms/step - loss: 0.7327 - accuracy: 0.9463 - precision: 0.9856 - recall: 0.8736 - val_loss: 0.6010 - val_accuracy: 0.9875 - val_precision: 0.9965 - val_recall: 0.9768
# Epoch 60/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7406 - accuracy: 0.9438 - precision: 0.9865 - recall: 0.8659
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.6109
#
# Epoch 60: val_loss did not improve from 0.60104
# 211/211 [==============================] - 9s 44ms/step - loss: 0.7406 - accuracy: 0.9438 - precision: 0.9865 - recall: 0.8659 - val_loss: 0.6109 - val_accuracy: 0.9841 - val_precision: 0.9911 - val_recall: 0.9664
# Epoch 61/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7394 - accuracy: 0.9428 - precision: 0.9827 - recall: 0.8644
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6043
#
# Epoch 61: val_loss did not improve from 0.60104
# 211/211 [==============================] - 24s 113ms/step - loss: 0.7403 - accuracy: 0.9430 - precision: 0.9828 - recall: 0.8647 - val_loss: 0.6043 - val_accuracy: 0.9837 - val_precision: 0.9911 - val_recall: 0.9675
# Epoch 62/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7382 - accuracy: 0.9457 - precision: 0.9852 - recall: 0.8683
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.6081
#
# Epoch 62: val_loss did not improve from 0.60104
# 211/211 [==============================] - 8s 39ms/step - loss: 0.7382 - accuracy: 0.9457 - precision: 0.9852 - recall: 0.8683 - val_loss: 0.6081 - val_accuracy: 0.9813 - val_precision: 0.9904 - val_recall: 0.9643
# Epoch 63/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7268 - accuracy: 0.9469 - precision: 0.9887 - recall: 0.8749
# ⚠️ Val-loss không cải thiện sau 4 epochs. Hiện tại: 0.6164
#
# Epoch 63: val_loss did not improve from 0.60104
# 211/211 [==============================] - 8s 38ms/step - loss: 0.7265 - accuracy: 0.9472 - precision: 0.9888 - recall: 0.8751 - val_loss: 0.6164 - val_accuracy: 0.9796 - val_precision: 0.9925 - val_recall: 0.9567
# Epoch 64/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7197 - accuracy: 0.9474 - precision: 0.9864 - recall: 0.8767
# ✅ Epoch 64: Val-Loss giảm thêm 0.0014! (Từ 0.6010 -> 0.5996)
#
# Epoch 64: val_loss improved from 0.60104 to 0.59960, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 8s 39ms/step - loss: 0.7202 - accuracy: 0.9475 - precision: 0.9865 - recall: 0.8769 - val_loss: 0.5996 - val_accuracy: 0.9872 - val_precision: 0.9936 - val_recall: 0.9709
# Epoch 65/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7170 - accuracy: 0.9531 - precision: 0.9872 - recall: 0.8784
# ✅ Epoch 65: Val-Accuracy tăng thêm 0.0017! (Từ 0.9875 -> 0.9893)
#
# ✅ Epoch 65: Val-Loss giảm thêm 0.0047! (Từ 0.5996 -> 0.5949)
#
# Epoch 65: val_loss improved from 0.59960 to 0.59492, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7170 - accuracy: 0.9531 - precision: 0.9872 - recall: 0.8784 - val_loss: 0.5949 - val_accuracy: 0.9893 - val_precision: 0.9957 - val_recall: 0.9733
# Epoch 66/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7187 - accuracy: 0.9548 - precision: 0.9874 - recall: 0.8838
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.5990
#
# Epoch 66: val_loss did not improve from 0.59492
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7187 - accuracy: 0.9548 - precision: 0.9874 - recall: 0.8838 - val_loss: 0.5990 - val_accuracy: 0.9889 - val_precision: 0.9957 - val_recall: 0.9730
# Epoch 67/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7186 - accuracy: 0.9492 - precision: 0.9868 - recall: 0.8800
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6054
#
# Epoch 67: val_loss did not improve from 0.59492
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7175 - accuracy: 0.9493 - precision: 0.9869 - recall: 0.8800 - val_loss: 0.6054 - val_accuracy: 0.9841 - val_precision: 0.9915 - val_recall: 0.9681
# Epoch 68/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7137 - accuracy: 0.9517 - precision: 0.9877 - recall: 0.8852
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.6024
#
# Epoch 68: val_loss did not improve from 0.59492
# 211/211 [==============================] - 9s 40ms/step - loss: 0.7134 - accuracy: 0.9515 - precision: 0.9877 - recall: 0.8849 - val_loss: 0.6024 - val_accuracy: 0.9830 - val_precision: 0.9898 - val_recall: 0.9706
# Epoch 69/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7146 - accuracy: 0.9502 - precision: 0.9905 - recall: 0.8835
# ⚠️ Val-loss không cải thiện sau 4 epochs. Hiện tại: 0.6010
#
# Epoch 69: val_loss did not improve from 0.59492
# 211/211 [==============================] - 8s 40ms/step - loss: 0.7146 - accuracy: 0.9502 - precision: 0.9905 - recall: 0.8835 - val_loss: 0.6010 - val_accuracy: 0.9844 - val_precision: 0.9936 - val_recall: 0.9675
# Epoch 70/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7213 - accuracy: 0.9510 - precision: 0.9871 - recall: 0.8834
# ⚠️ Val-loss không cải thiện sau 5 epochs. Hiện tại: 0.6044
#
# Epoch 70: val_loss did not improve from 0.59492
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7213 - accuracy: 0.9510 - precision: 0.9871 - recall: 0.8834 - val_loss: 0.6044 - val_accuracy: 0.9834 - val_precision: 0.9915 - val_recall: 0.9657
# Epoch 71/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7030 - accuracy: 0.9557 - precision: 0.9889 - recall: 0.8903
# ⚠️ Val-loss không cải thiện sau 6 epochs. Hiện tại: 0.5956
#
# Epoch 71: val_loss did not improve from 0.59492
# 211/211 [==============================] - 8s 40ms/step - loss: 0.7025 - accuracy: 0.9559 - precision: 0.9890 - recall: 0.8908 - val_loss: 0.5956 - val_accuracy: 0.9841 - val_precision: 0.9926 - val_recall: 0.9699
# Epoch 72/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7203 - accuracy: 0.9499 - precision: 0.9879 - recall: 0.8825
# ✅ Epoch 72: Val-Loss giảm thêm 0.0004! (Từ 0.5949 -> 0.5945)
#
# Epoch 72: val_loss improved from 0.59492 to 0.59452, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7203 - accuracy: 0.9499 - precision: 0.9879 - recall: 0.8825 - val_loss: 0.5945 - val_accuracy: 0.9875 - val_precision: 0.9943 - val_recall: 0.9709
# Epoch 73/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7154 - accuracy: 0.9539 - precision: 0.9915 - recall: 0.8837
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.5976
#
# Epoch 73: val_loss did not improve from 0.59452
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7153 - accuracy: 0.9537 - precision: 0.9915 - recall: 0.8834 - val_loss: 0.5976 - val_accuracy: 0.9837 - val_precision: 0.9936 - val_recall: 0.9695
# Epoch 74/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7134 - accuracy: 0.9562 - precision: 0.9897 - recall: 0.8850
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.5955
#
# Epoch 74: val_loss did not improve from 0.59452
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7134 - accuracy: 0.9562 - precision: 0.9897 - recall: 0.8850 - val_loss: 0.5955 - val_accuracy: 0.9872 - val_precision: 0.9936 - val_recall: 0.9730
# Epoch 75/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7081 - accuracy: 0.9557 - precision: 0.9915 - recall: 0.8907
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.5948
#
# Epoch 75: val_loss did not improve from 0.59452
# 211/211 [==============================] - 9s 40ms/step - loss: 0.7087 - accuracy: 0.9556 - precision: 0.9916 - recall: 0.8908 - val_loss: 0.5948 - val_accuracy: 0.9855 - val_precision: 0.9926 - val_recall: 0.9733
# Epoch 76/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7084 - accuracy: 0.9554 - precision: 0.9897 - recall: 0.8842
# ⚠️ Val-loss không cải thiện sau 4 epochs. Hiện tại: 0.5947
#
# Epoch 76: val_loss did not improve from 0.59452
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7092 - accuracy: 0.9556 - precision: 0.9897 - recall: 0.8844 - val_loss: 0.5947 - val_accuracy: 0.9872 - val_precision: 0.9933 - val_recall: 0.9733
# Epoch 77/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.9584 - precision: 0.9907 - recall: 0.8882
# ✅ Epoch 77: Val-Loss giảm thêm 0.0007! (Từ 0.5945 -> 0.5938)
#
# Epoch 77: val_loss improved from 0.59452 to 0.59381, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7100 - accuracy: 0.9583 - precision: 0.9907 - recall: 0.8883 - val_loss: 0.5938 - val_accuracy: 0.9855 - val_precision: 0.9936 - val_recall: 0.9720
# Epoch 78/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7105 - accuracy: 0.9571 - precision: 0.9878 - recall: 0.8881
# ✅ Epoch 78: Val-Loss giảm thêm 0.0007! (Từ 0.5938 -> 0.5931)
#
# Epoch 78: val_loss improved from 0.59381 to 0.59312, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 41ms/step - loss: 0.7105 - accuracy: 0.9571 - precision: 0.9878 - recall: 0.8881 - val_loss: 0.5931 - val_accuracy: 0.9844 - val_precision: 0.9936 - val_recall: 0.9726
# Epoch 79/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7003 - accuracy: 0.9592 - precision: 0.9912 - recall: 0.8897
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.5935
#
# Epoch 79: val_loss did not improve from 0.59312
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7002 - accuracy: 0.9594 - precision: 0.9912 - recall: 0.8899 - val_loss: 0.5935 - val_accuracy: 0.9865 - val_precision: 0.9940 - val_recall: 0.9730
# Epoch 80/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7121 - accuracy: 0.9523 - precision: 0.9868 - recall: 0.8828
# ✅ Epoch 80: Val-Loss giảm thêm 0.0009! (Từ 0.5931 -> 0.5922)
#
# Epoch 80: val_loss improved from 0.59312 to 0.59219, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 42ms/step - loss: 0.7124 - accuracy: 0.9522 - precision: 0.9869 - recall: 0.8830 - val_loss: 0.5922 - val_accuracy: 0.9872 - val_precision: 0.9940 - val_recall: 0.9737
# Epoch 81/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7175 - accuracy: 0.9509 - precision: 0.9887 - recall: 0.8838
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.5925
#
# Epoch 81: val_loss did not improve from 0.59219
# 211/211 [==============================] - 12s 55ms/step - loss: 0.7175 - accuracy: 0.9509 - precision: 0.9887 - recall: 0.8838 - val_loss: 0.5925 - val_accuracy: 0.9851 - val_precision: 0.9940 - val_recall: 0.9733
# Epoch 82/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7102 - accuracy: 0.9557 - precision: 0.9885 - recall: 0.8851
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.6025
#
# Epoch 82: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 49ms/step - loss: 0.7100 - accuracy: 0.9559 - precision: 0.9886 - recall: 0.8855 - val_loss: 0.6025 - val_accuracy: 0.9855 - val_precision: 0.9925 - val_recall: 0.9681
# Epoch 83/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7239 - accuracy: 0.9484 - precision: 0.9855 - recall: 0.8766
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.6013
#
# Epoch 83: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 46ms/step - loss: 0.7239 - accuracy: 0.9484 - precision: 0.9855 - recall: 0.8766 - val_loss: 0.6013 - val_accuracy: 0.9848 - val_precision: 0.9961 - val_recall: 0.9616
# Epoch 84/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7137 - accuracy: 0.9551 - precision: 0.9884 - recall: 0.8860
# ⚠️ Val-loss không cải thiện sau 4 epochs. Hiện tại: 0.5952
#
# Epoch 84: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 47ms/step - loss: 0.7134 - accuracy: 0.9553 - precision: 0.9884 - recall: 0.8865 - val_loss: 0.5952 - val_accuracy: 0.9893 - val_precision: 0.9961 - val_recall: 0.9747
# Epoch 85/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7133 - accuracy: 0.9571 - precision: 0.9899 - recall: 0.8881
# ⚠️ Val-loss không cải thiện sau 5 epochs. Hiện tại: 0.6143
#
# Epoch 85: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 47ms/step - loss: 0.7133 - accuracy: 0.9571 - precision: 0.9899 - recall: 0.8881 - val_loss: 0.6143 - val_accuracy: 0.9823 - val_precision: 0.9918 - val_recall: 0.9623
# Epoch 86/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7235 - accuracy: 0.9493 - precision: 0.9895 - recall: 0.8745
# ⚠️ Val-loss không cải thiện sau 6 epochs. Hiện tại: 0.5992
#
# Epoch 86: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 47ms/step - loss: 0.7236 - accuracy: 0.9496 - precision: 0.9896 - recall: 0.8748 - val_loss: 0.5992 - val_accuracy: 0.9868 - val_precision: 0.9925 - val_recall: 0.9657
# Epoch 87/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7198 - accuracy: 0.9495 - precision: 0.9886 - recall: 0.8825
# ⚠️ Val-loss không cải thiện sau 7 epochs. Hiện tại: 0.6016
#
# Epoch 87: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 46ms/step - loss: 0.7200 - accuracy: 0.9496 - precision: 0.9887 - recall: 0.8825 - val_loss: 0.6016 - val_accuracy: 0.9823 - val_precision: 0.9911 - val_recall: 0.9664
# Epoch 88/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7109 - accuracy: 0.9547 - precision: 0.9900 - recall: 0.8872
# ✅ Epoch 88: Val-Accuracy tăng thêm 0.0042! (Từ 0.9893 -> 0.9934)
#
# ⚠️ Val-loss không cải thiện sau 8 epochs. Hiện tại: 0.5966
#
# Epoch 88: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 49ms/step - loss: 0.7112 - accuracy: 0.9546 - precision: 0.9901 - recall: 0.8870 - val_loss: 0.5966 - val_accuracy: 0.9934 - val_precision: 0.9979 - val_recall: 0.9789
# Epoch 89/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7096 - accuracy: 0.9531 - precision: 0.9907 - recall: 0.8880
# ⚠️ Val-loss không cải thiện sau 9 epochs. Hiện tại: 0.5949
#
# Epoch 89: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 47ms/step - loss: 0.7096 - accuracy: 0.9531 - precision: 0.9907 - recall: 0.8880 - val_loss: 0.5949 - val_accuracy: 0.9855 - val_precision: 0.9933 - val_recall: 0.9720
# Epoch 90/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7027 - accuracy: 0.9562 - precision: 0.9888 - recall: 0.8920
# ⚠️ Val-loss không cải thiện sau 10 epochs. Hiện tại: 0.5961
#
# Epoch 90: val_loss did not improve from 0.59219
# 211/211 [==============================] - 9s 45ms/step - loss: 0.7027 - accuracy: 0.9562 - precision: 0.9888 - recall: 0.8920 - val_loss: 0.5961 - val_accuracy: 0.9875 - val_precision: 0.9937 - val_recall: 0.9758
# Epoch 91/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7112 - accuracy: 0.9526 - precision: 0.9892 - recall: 0.8896
# ⚠️ Val-loss không cải thiện sau 11 epochs. Hiện tại: 0.5967
#
# Epoch 91: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 47ms/step - loss: 0.7108 - accuracy: 0.9528 - precision: 0.9893 - recall: 0.8898 - val_loss: 0.5967 - val_accuracy: 0.9889 - val_precision: 0.9944 - val_recall: 0.9765
# Epoch 92/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7125 - accuracy: 0.9533 - precision: 0.9901 - recall: 0.8874
# ⚠️ Val-loss không cải thiện sau 12 epochs. Hiện tại: 0.5976
#
# Epoch 92: val_loss did not improve from 0.59219
# 211/211 [==============================] - 10s 47ms/step - loss: 0.7125 - accuracy: 0.9533 - precision: 0.9901 - recall: 0.8874 - val_loss: 0.5976 - val_accuracy: 0.9868 - val_precision: 0.9943 - val_recall: 0.9675
# Epoch 93/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7093 - accuracy: 0.9528 - precision: 0.9900 - recall: 0.8834
# ✅ Epoch 93: Val-Loss giảm thêm 0.0055! (Từ 0.5922 -> 0.5866)
#
# Epoch 93: val_loss improved from 0.59219 to 0.58664, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 10s 46ms/step - loss: 0.7093 - accuracy: 0.9528 - precision: 0.9900 - recall: 0.8834 - val_loss: 0.5866 - val_accuracy: 0.9917 - val_precision: 0.9968 - val_recall: 0.9775
# Epoch 94/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7043 - accuracy: 0.9580 - precision: 0.9911 - recall: 0.8928
# ⚠️ Val-loss không cải thiện sau 1 epochs. Hiện tại: 0.5923
#
# Epoch 94: val_loss did not improve from 0.58664
# 211/211 [==============================] - 10s 47ms/step - loss: 0.7038 - accuracy: 0.9580 - precision: 0.9911 - recall: 0.8929 - val_loss: 0.5923 - val_accuracy: 0.9855 - val_precision: 0.9943 - val_recall: 0.9685
# Epoch 95/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7087 - accuracy: 0.9556 - precision: 0.9904 - recall: 0.8905
# ⚠️ Val-loss không cải thiện sau 2 epochs. Hiện tại: 0.5987
#
# Epoch 95: val_loss did not improve from 0.58664
# 211/211 [==============================] - 10s 49ms/step - loss: 0.7087 - accuracy: 0.9556 - precision: 0.9904 - recall: 0.8905 - val_loss: 0.5987 - val_accuracy: 0.9848 - val_precision: 0.9915 - val_recall: 0.9685
# Epoch 96/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7153 - accuracy: 0.9492 - precision: 0.9880 - recall: 0.8848
# ⚠️ Val-loss không cải thiện sau 3 epochs. Hiện tại: 0.5942
#
# Epoch 96: val_loss did not improve from 0.58664
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7156 - accuracy: 0.9493 - precision: 0.9879 - recall: 0.8849 - val_loss: 0.5942 - val_accuracy: 0.9882 - val_precision: 0.9940 - val_recall: 0.9709
# Epoch 97/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.9567 - precision: 0.9896 - recall: 0.8861
# ⚠️ Val-loss không cải thiện sau 4 epochs. Hiện tại: 0.5918
#
# Epoch 97: val_loss did not improve from 0.58664
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7065 - accuracy: 0.9567 - precision: 0.9896 - recall: 0.8861 - val_loss: 0.5918 - val_accuracy: 0.9889 - val_precision: 0.9950 - val_recall: 0.9720
# Epoch 98/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7025 - accuracy: 0.9586 - precision: 0.9901 - recall: 0.8913
# ⚠️ Val-loss không cải thiện sau 5 epochs. Hiện tại: 0.5946
#
# Epoch 98: val_loss did not improve from 0.58664
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7025 - accuracy: 0.9586 - precision: 0.9901 - recall: 0.8913 - val_loss: 0.5946 - val_accuracy: 0.9875 - val_precision: 0.9937 - val_recall: 0.9754
# Epoch 99/100
# 210/211 [============================>.] - ETA: 0s - loss: 0.7027 - accuracy: 0.9586 - precision: 0.9922 - recall: 0.8964
# ⚠️ Val-loss không cải thiện sau 6 epochs. Hiện tại: 0.5930
#
# Epoch 99: val_loss did not improve from 0.58664
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7025 - accuracy: 0.9586 - precision: 0.9923 - recall: 0.8968 - val_loss: 0.5930 - val_accuracy: 0.9855 - val_precision: 0.9940 - val_recall: 0.9699
# Epoch 100/100
# 211/211 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.9588 - precision: 0.9907 - recall: 0.8968
# ✅ Epoch 100: Val-Loss giảm thêm 0.0004! (Từ 0.5866 -> 0.5862)
#
# Epoch 100: val_loss improved from 0.58664 to 0.58620, saving model to traffic_sign_cleaned_final.h5
# 211/211 [==============================] - 9s 43ms/step - loss: 0.7051 - accuracy: 0.9588 - precision: 0.9907 - recall: 0.8968 - val_loss: 0.5862 - val_accuracy: 0.9900 - val_precision: 0.9947 - val_recall: 0.9737
# Restoring model weights from the end of the best epoch: 88.
# ✅ Đã lưu mô hình sạch sẽ cho QAT: traffic_sign_cleaned_final.h5

# %% [markdown]
# # Continue

# %%
import tensorflow as tf
import tensorflow_model_optimization as tfmot

# 1. Nạp model trong Scope của TFMOT để Keras hiểu các lớp QuantizeWrapper
with tfmot.quantization.keras.quantize_scope():
    # Nạp lại file đã train ở Cell 1
    loaded_model = tf.keras.models.load_model('traffic_sign_cleaned_final.h5')


# 2. Khởi tạo Converter từ model vừa nạp
# Converter sẽ tự động "Strip" (lột vỏ) các lớp bọc cho bạn
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# 3. Cung cấp dữ liệu mẫu (Representative Dataset)
# CỰC KỲ QUAN TRỌNG: Để TFLite tính toán dải giá trị cho INT8
def representative_dataset():
    # Đảm bảo val_ds đã được định nghĩa ở cell này (hoặc nạp lại data)
    for images, _ in val_ds.unbatch().batch(1).take(100):
        yield [tf.cast(images, tf.float32)]

converter.representative_dataset = representative_dataset

# 4. Ép kiểu INT8 toàn phần để chạy nhanh trên ESP32-S3
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

# 5. Thực hiện chuyển đổi và lưu file
tflite_model = converter.convert()

with open('traffic_sign_final_int8.tflite', 'wb') as f:
    f.write(tflite_model)

print(f"🚀 Xuất file TFLite thành công! Kích thước: {len(tflite_model)/1024:.2f} KB")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ngong\AppData\Local\Temp\tmptxdlq8vd\assets
# INFO:tensorflow:Assets written to: C:\Users\ngong\AppData\Local\Temp\tmptxdlq8vd\assets
# c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 🚀 Xuất file TFLite thành công! Kích thước: 62.92 KB

# %% [markdown]
# # Model Evaluation

# %%
import time
import numpy as np
import tensorflow as tf

# 1. Load TFLite Model và cấp phát bộ nhớ
interpreter = tf.lite.Interpreter(model_path="traffic_sign_final_int8.tflite")
interpreter.allocate_tensors()

# Lấy thông tin input/output
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
input_index = input_details[0]['index']
output_index = output_details[0]['index']

# Quan trọng: Lấy thông tin Quantization để chuẩn hóa ảnh đầu vào đúng kiểu INT8
input_scale, input_zero_point = input_details[0]['quantization']

# 2. Chuẩn bị biến lưu trữ kết quả benchmark
total_inference_time = 0
correct_predictions = 0
total_images = 0

print("🚀 Đang bắt đầu đánh giá Model...")
print("-" * 40)

# Duyệt qua tập Validation (val_ds đã định nghĩa ở các bước trước)
# Chúng ta unbatch để đo thời gian cho từng ảnh đơn lẻ
for images, labels in val_ds.unbatch().take(500):  # Test trên 500 mẫu
    total_images += 1
    
    # --- TIỀN XỬ LÝ (Preprocessing) ---
    # Chuyển ảnh về dạng mà model INT8 yêu cầu
    img_array = images.numpy()
    if input_scale != 0:
        img_array = img_array / input_scale + input_zero_point
    
    # Ép kiểu sang INT8 và thêm dimension batch (1, 32, 32, 3)
    input_data = np.expand_dims(img_array.astype(np.int8), axis=0)
    
    # --- INFERENCE (Đo thời gian) ---
    start_time = time.perf_counter()
    
    interpreter.set_tensor(input_index, input_data)
    interpreter.invoke()
    output_data = interpreter.get_tensor(output_index)
    
    end_time = time.perf_counter()
    
    # Cộng dồn thời gian (tính bằng miligiây)
    total_inference_time += (end_time - start_time) * 1000
    
    # --- KIỂM TRA ĐỘ CHÍNH XÁC ---
    predicted_label = np.argmax(output_data[0])
    true_label = labels.numpy()
    
    # Comment cái này nếu không one-hot
    true_label_idx = np.argmax(labels.numpy()) # Lấy vị trí của số 1 trong mảng One-Hot

    if predicted_label == true_label_idx:
        correct_predictions += 1

# 3. TÍNH TOÁN VÀ LOG KẾT QUẢ
avg_inference_time = total_inference_time / total_images
accuracy = (correct_predictions / total_images) * 100

print("-" * 40)
print(f"📊 KẾT QUẢ BENCHMARK (Trên PC):")
print(f"🔹 Tổng số ảnh kiểm tra: {total_images}")
print(f"🔹 Độ chính xác (Accuracy): {accuracy:.2f}%")
print(f"🔹 Tổng thời gian Inference : {total_inference_time:.2f} ms")
print(f"🔹 Thời gian Inference trung bình: {avg_inference_time:.2f} ms / ảnh")
print("-" * 40)
# Out:
# 🚀 Đang bắt đầu đánh giá Model...
# ----------------------------------------
# ----------------------------------------
# 📊 KẾT QUẢ BENCHMARK (Trên PC):
# 🔹 Tổng số ảnh kiểm tra: 500
# 🔹 Độ chính xác (Accuracy): 99.20%
# 🔹 Tổng thời gian Inference : 26.21 ms
# 🔹 Thời gian Inference trung bình: 0.05 ms / ảnh
# ----------------------------------------
# c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %% [markdown]
# # Chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# ==========================================
# 1. HÀM VẼ BIỂU ĐỒ HISTORY (ACCURACY & LOSS)
# ==========================================
def plot_training_results(history):
    # Lấy dữ liệu từ object history của Keras
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))

    # Biểu đồ Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy', color='#1f77b4', linewidth=2)
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='#ff7f0e', linewidth=2)
    plt.title('Training and Validation Accuracy', fontsize=12)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.7)

    # Biểu đồ Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss', color='#d62728', linewidth=2)
    plt.plot(epochs_range, val_loss, label='Validation Loss', color='#2ca02c', linewidth=2)
    plt.title('Training and Validation Loss', fontsize=12)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

# Gọi hàm ngay sau khi qat_model.fit()
plot_training_results(history)


# ==========================================
# 2. VẼ CONFUSION MATRIX (MA TRẬN NHẦM LẪN)
# ==========================================
print("🚀 Đang tính toán dự đoán trên tập Validation...")

# Dự đoán nhãn từ qat_model (dùng tập val_ds)
y_pred = []
y_true = []

# Duyệt qua từng batch trong val_ds để lấy nhãn thật và nhãn dự đoán
for images, labels in val_ds:
    # preds = qat_model.predict(images, verbose=0)
    # y_pred.extend(np.argmax(preds, axis=1))
    # y_true.extend(labels.numpy())

    # ONE-HOT======================================
    preds = qat_model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    # 2. Xử lý y_true: Chuyển từ One-Hot (do Label Smoothing) về Integer
    # labels lúc này có dạng (batch_size, num_classes)
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    # ONE-HOT======================================

# Tính Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Vẽ biểu đồ nhiệt Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=range(NUM_CLASSES), 
            yticklabels=range(NUM_CLASSES))

plt.title('Confusion Matrix - Traffic Sign Recognition', fontsize=14)
plt.xlabel('Nhãn Dự Đoán (Predicted)', fontsize=12)
plt.ylabel('Nhãn Thực Tế (True)', fontsize=12)
plt.show()
# Out:
# 🚀 Đang tính toán dự đoán trên tập Validation...
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 352ms/step

# %% [markdown]
# # Log

# %%
# ==========================================
# TEST TFLITE MODEL & XUẤT CSV (BẢN CHUẨN DUT)
# ==========================================
import os
import glob
import numpy as np
import pandas as pd
import tensorflow as tf

# 1. Load ĐÚNG file TFLite mới nhất bạn vừa convert thành công
# (Hãy đảm bảo tên file này khớp với file ở Cell Convert)
MODEL_PATH = "traffic_sign_final_int8.tflite" 
interpreter = tf.lite.Interpreter(model_path=MODEL_PATH)
interpreter.allocate_tensors()

# Lấy thông tin Input/Output
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
input_index = input_details[0]['index']
output_index = output_details[0]['index']

# Lấy thông tin Quantization (Cực kỳ quan trọng cho INT8)
input_scale, input_zero_point = input_details[0]['quantization']

# 2. Quét danh sách ảnh Test
# Lưu ý: Sắp xếp theo tên để đảm bảo thứ tự trong CSV
test_images_paths = glob.glob(os.path.join(TEST_DIR, '*.png'))
test_images_paths.sort() 

results = []

print(f"🚀 Đang xử lý {len(test_images_paths)} ảnh test...")

for img_path in test_images_paths:
    # Lấy ID từ tên file (ví dụ: '001.png' -> '001')
    img_id = os.path.basename(img_path).split('.')[0]
    
    # --- TIỀN XỬ LÝ (Phải khớp 100% với lúc Train) ---
    # Load ảnh dạng GRAYSCALE (vì model của bạn train với color_mode='grayscale')
    img = tf.keras.utils.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE), color_mode='grayscale')
    img_array = tf.keras.utils.img_to_array(img)
    
    # Bước A: Rescaling 1./255 (giống normalization_layer lúc train)
    img_array = img_array / 255.0
    
    # Bước B: Quantization Scaling (Ép float sang INT8)
    if input_scale != 0:
        img_array = (img_array / input_scale) + input_zero_point
    
    # Thêm batch dimension và ép kiểu int8
    input_data = np.expand_dims(img_array.astype(np.int8), axis=0)
    
    # --- CHẠY INFERENCE ---
    interpreter.set_tensor(input_index, input_data)
    interpreter.invoke()
    output_data = interpreter.get_tensor(output_index)[0]
    
    # Lấy class có xác suất cao nhất
    predicted_class = np.argmax(output_data)
    
    results.append({'Id': img_id, 'Label': int(predicted_class)})

# 3. XUẤT FILE CSV
submission_df = pd.DataFrame(results)

# Đảm bảo cột Id được lưu đúng định dạng (ví dụ 0001 thay vì 1 nếu cần)
submission_df.to_csv('submission.csv', index=False)

print("-" * 30)
print(f"✅ Đã xuất file thành công: submission.csv")
print(f"🔹 Tổng cộng: {len(submission_df)} dòng.")
print(submission_df.head()) # Xem trước 5 dòng đầu
# Out:
# c:\Users\ngong\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# 🚀 Đang xử lý 1545 ảnh test...
# ------------------------------
# ✅ Đã xuất file thành công: submission.csv
# 🔹 Tổng cộng: 1545 dòng.
#       Id  Label
# 0  00000      2
# 1  00007      2
# 2  00008      0
# 3  00012      2
# 4  00013      2
